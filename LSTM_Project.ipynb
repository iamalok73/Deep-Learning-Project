# %% [markdown]
# <a href="https://colab.research.google.com/github/iamalok73/Deep-Learning-Project/blob/main/LSTM_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
text = """Deep learning is a subset of machine learning.
Machine learning is a part of artificial intelligence.
Artificial intelligence is transforming the world.
Data science is used to extract insights from data.
Python is widely used in data science.
Neural networks are inspired by the human brain.
LSTM is a type of recurrent neural network.
Recurrent neural networks are used for sequence data.
Transformers are powerful models for NLP tasks.
Natural language processing helps machines understand text.
Deep learning models require large amounts of data.
AI is used in healthcare, finance, and education."""

# %%
print(text)
# Out:
# Deep learning is a subset of machine learning.
# Machine learning is a part of artificial intelligence.
# Artificial intelligence is transforming the world.
# Data science is used to extract insights from data.
# Python is widely used in data science.
# Neural networks are inspired by the human brain.
# LSTM is a type of recurrent neural network.
# Recurrent neural networks are used for sequence data.
# Transformers are powerful models for NLP tasks.
# Natural language processing helps machines understand text.
# Deep learning models require large amounts of data.
# AI is used in healthcare, finance, and education.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])

# %%
print(len(tokenizer.index_word))
# Out:
# 56

# %%
total_words = len(tokenizer.word_index) + 1

# %%
print(total_words)
# Out:
# 57

# %%
input_sequences = []

for line in text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    # print(token_list)
    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

# %%
(input_sequences)
# Out:
# [[9, 3],
#  [9, 3, 1],
#  [9, 3, 1, 6],
#  [9, 3, 1, 6, 20],
#  [9, 3, 1, 6, 20, 4],
#  [9, 3, 1, 6, 20, 4, 10],
#  [9, 3, 1, 6, 20, 4, 10, 3],
#  [10, 3],
#  [10, 3, 1],
#  [10, 3, 1, 6],
#  [10, 3, 1, 6, 21],
#  [10, 3, 1, 6, 21, 4],
#  [10, 3, 1, 6, 21, 4, 11],
#  [10, 3, 1, 6, 21, 4, 11, 12],
#  [11, 12],
#  [11, 12, 1],
#  [11, 12, 1, 22],
#  [11, 12, 1, 22, 13],
#  [11, 12, 1, 22, 13, 23],
#  [2, 14],
#  [2, 14, 1],
#  [2, 14, 1, 5],
#  [2, 14, 1, 5, 24],
#  [2, 14, 1, 5, 24, 25],
#  [2, 14, 1, 5, 24, 25, 26],
#  [2, 14, 1, 5, 24, 25, 26, 27],
#  [2, 14, 1, 5, 24, 25, 26, 27, 2],
#  [28, 1],
#  [28, 1, 29],
#  [28, 1, 29, 5],
#  [28, 1, 29, 5, 15],
#  [28, 1, 29, 5, 15, 2],
#  [28, 1, 29, 5, 15, 2, 14],
#  [7, 16],
#  [7, 16, 8],
#  [7, 16, 8, 30],
#  [7, 16, 8, 30, 31],
#  [7, 16, 8, 30, 31, 13],
#  [7, 16, 8, 30, 31, 13, 32],
#  [7, 16, 8, 30, 31, 13, 32, 33],
#  [34, 1],
#  [34, 1, 6],
#  [34, 1, 6, 35],
#  [34, 1, 6, 35, 4],
#  [34, 1, 6, 35, 4, 17],
# ...

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = max([len(x) for x in input_sequences])

input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

# %%
input_sequences
# Out:
# array([[ 0,  0,  0,  0,  0,  0,  0,  9,  3],
#        [ 0,  0,  0,  0,  0,  0,  9,  3,  1],
#        [ 0,  0,  0,  0,  0,  9,  3,  1,  6],
#        [ 0,  0,  0,  0,  9,  3,  1,  6, 20],
#        [ 0,  0,  0,  9,  3,  1,  6, 20,  4],
#        [ 0,  0,  9,  3,  1,  6, 20,  4, 10],
#        [ 0,  9,  3,  1,  6, 20,  4, 10,  3],
#        [ 0,  0,  0,  0,  0,  0,  0, 10,  3],
#        [ 0,  0,  0,  0,  0,  0, 10,  3,  1],
#        [ 0,  0,  0,  0,  0, 10,  3,  1,  6],
#        [ 0,  0,  0,  0, 10,  3,  1,  6, 21],
#        [ 0,  0,  0, 10,  3,  1,  6, 21,  4],
#        [ 0,  0, 10,  3,  1,  6, 21,  4, 11],
#        [ 0, 10,  3,  1,  6, 21,  4, 11, 12],
#        [ 0,  0,  0,  0,  0,  0,  0, 11, 12],
#        [ 0,  0,  0,  0,  0,  0, 11, 12,  1],
#        [ 0,  0,  0,  0,  0, 11, 12,  1, 22],
#        [ 0,  0,  0,  0, 11, 12,  1, 22, 13],
#        [ 0,  0,  0, 11, 12,  1, 22, 13, 23],
#        [ 0,  0,  0,  0,  0,  0,  0,  2, 14],
#        [ 0,  0,  0,  0,  0,  0,  2, 14,  1],
# ...

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes=total_words)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential()

model.add(Embedding(total_words, 100, input_length=max_len-1))
model.add(LSTM(150))
model.add(Dense(total_words, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, y, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.0500 - loss: 4.0394
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1000 - loss: 4.0183
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0875 - loss: 3.9900
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.0875 - loss: 3.9483
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.0875 - loss: 3.8665
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.0875 - loss: 3.7295
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.0875 - loss: 3.7429
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0875 - loss: 3.6827
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1000 - loss: 3.6195
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1000 - loss: 3.6011
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1125 - loss: 3.5634
# Epoch 12/50
# ...

# %%
def predict_next_word(seed_text):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')

    predicted = np.argmax(model.predict(token_list), axis=-1)

    for word, index in tokenizer.word_index.items():
        if index == predicted:
            return word
