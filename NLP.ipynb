# %% [markdown]
# # Natural language Processing
# - Nlp is a field of study that focused on the interaction on the interaction between computers and human language, it involves the developement of Algorith and models to enables computer to understand , interpret and generate humn language.

# %%
txt = "Hello My Name Is Alok Kumar."

# %%
a = txt.lower()
print(a)
# Out:
# hello my name is alok kumar.

# %%
b = txt.casefold()
print(b)
# Out:
# hello my name is alok kumar.

# %% [markdown]
# # Special Char Removing

# %%
import re

# %%
txt = "Hello My Name Is Alok Kumar @new #Location."

# %%
import re
new = re.sub(r"[a-zA-Z0-9]", " ", txt)
print(new)
# Out:
#                             @    #        .

# %%
new = re.sub(r"[^a-zA-Z0-9]", " ", txt)
print(new)
b = new.lower()
print(b)
# Out:
# Hello My Name Is Alok Kumar  new  Location
# hello my name is alok kumar  new  location

# %% [markdown]
# # Tokenization
# - Tokenization is the process of breaking down a piece of text into smaller units called tokens. These tokens can be words, sentences, or even subwords, depending on the rules applied. Tokenization is a fundamental step in Natural Language Processing (NLP) as it helps in preparing the text for further analysis or processing.

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AlokVerma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
txt = "Hello My Name Is  $ Alok @ Kumar.This is School bag."

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AlokVerma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\AlokVerma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
nltk.sent_tokenize(txt)
# Out:
# ['Hello My Name Is  $ Alok @ Kumar.This is Schoo bag.']

# %%
nltk.word_tokenize(txt)
# Out:
# ['Hello',
#  'My',
#  'Name',
#  'Is',
#  '$',
#  'Alok',
#  '@',
#  'Kumar.This',
#  'is',
#  'Schoo',
#  'bag',
#  '.']

# %% [markdown]
# # Handling Contraction
#
# - In Natural Language Processing (NLP), contractions are shortened forms of words or phrases, such as "can't" for "cannot" or "it's" for "it is." Expanding these contractions is a crucial preprocessing step to improve text understanding, maintain context, and enhance the performance of downstream tasks like sentiment analysis, machine translation, and named entity recognition.

# %%
pip install contractions
# Out:
# ...
#   Using cached contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Using cached textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Using cached anyascii-0.3.3-py3-none-any.whl (345 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------------------------------------- 4/4 [contractions]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import contractions

# %%
detail = "I'm living with my Dad house. Today I'll not going to school."
new = contractions.fix(detail)

print(detail)
print(new)

print(nltk.word_tokenize(new))
# Out:
# I'm living with my Dad house. Today I'll not going to school.
# I am living with my Dad house. Today I will not going to school.
# ['I', 'am', 'living', 'with', 'my', 'Dad', 'house', '.', 'Today', 'I', 'will', 'not', 'going', 'to', 'school', '.']

# %%
print(new)
# Out:
# I am living with my Dad house. Today I will not going to school.

# %% [markdown]
# # Tokenization word and sentance

# %%
import nltk
from nltk.tokenize import word_tokenize , sent_tokenize

# %%
detail = "I'm living with my Dad's house. And i live happily"

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AlokVerma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nw = contractions.fix(detail)
print(word_tokenize(nw))
# Out:
# ['I', 'am', 'living', 'with', 'my', 'Dad', "'s", 'house', '.', 'And', 'i', 'live', 'happily']

# %%
sent_tokenize(nw)
# Out:
# ["I am living with my Dad's house.", 'And i live happily']

# %% [markdown]
# # Stop word Removing

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AlokVerma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AlokVerma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
detail = "I'm living with my Dad house. Today I'll not going to school."
new = contractions.fix(detail)

x = (word_tokenize(new))
print(x)

stop_words = set(stopwords.words('english'))

# remove stopwords
filtered = [i for i in x if i.lower() not in stop_words]

print(filtered)
# Out:
# ['I', 'am', 'living', 'with', 'my', 'Dad', 'house', '.', 'Today', 'I', 'will', 'not', 'going', 'to', 'school', '.']
# ['living', 'Dad', 'house', '.', 'Today', 'going', 'school', '.']
